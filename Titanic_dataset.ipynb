# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/Collab/titanic/train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # Handling NULL Values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1 = df.dropna()
df1
# Out:
#      PassengerId  Survived  Pclass  ...     Fare        Cabin  Embarked
# 1              2         1       1  ...  71.2833          C85         C
# 3              4         1       1  ...  53.1000         C123         S
# 6              7         0       1  ...  51.8625          E46         S
# 10            11         1       3  ...  16.7000           G6         S
# 11            12         1       1  ...  26.5500         C103         S
# ..           ...       ...     ...  ...      ...          ...       ...
# 871          872         1       1  ...  52.5542          D35         S
# 872          873         0       1  ...   5.0000  B51 B53 B55         S
# 879          880         1       1  ...  83.1583          C50         C
# 887          888         1       1  ...  30.0000          B42         S
# 889          890         1       1  ...  30.0000         C148         C
#
# [183 rows x 12 columns]

# %%
df2 = df.drop(['Name','PassengerId'],axis = 1)
df2
# Out:
#      Survived  Pclass     Sex   Age  ...            Ticket     Fare Cabin  Embarked
# 0           0       3    male  22.0  ...         A/5 21171   7.2500   NaN         S
# 1           1       1  female  38.0  ...          PC 17599  71.2833   C85         C
# 2           1       3  female  26.0  ...  STON/O2. 3101282   7.9250   NaN         S
# 3           1       1  female  35.0  ...            113803  53.1000  C123         S
# 4           0       3    male  35.0  ...            373450   8.0500   NaN         S
# ..        ...     ...     ...   ...  ...               ...      ...   ...       ...
# 886         0       2    male  27.0  ...            211536  13.0000   NaN         S
# 887         1       1  female  19.0  ...            112053  30.0000   B42         S
# 888         0       3  female   NaN  ...        W./C. 6607  23.4500   NaN         S
# 889         1       1    male  26.0  ...            111369  30.0000  C148         C
# ...

# %% [markdown]
# # Dividing dataset with respect to Sex, Survived

# %%
df3 = df1.loc[(df1.Sex == 'male') & (df1.Survived == 1) ]
df3.head()
# Out:
#      PassengerId  Survived  Pclass  ...     Fare    Cabin  Embarked
# 21            22         1       2  ...  13.0000      D56         S
# 23            24         1       1  ...  35.5000       A6         S
# 97            98         1       1  ...  63.3583  D10 D12         C
# 183          184         1       2  ...  39.0000       F4         S
# 193          194         1       2  ...  26.0000       F2         S
#
# [5 rows x 12 columns]

# %%
df4 = df1.loc[(df1.Sex == 'female') & (df1.Survived == 1) ]
df4.head()
# Out:
#     PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 1             2         1       1  ...  71.2833   C85         C
# 3             4         1       1  ...  53.1000  C123         S
# 10           11         1       3  ...  16.7000    G6         S
# 11           12         1       1  ...  26.5500  C103         S
# 52           53         1       1  ...  76.7292   D33         C
#
# [5 rows x 12 columns]

# %%
df5 = df.iloc[0:55,2:7]
df5.head()
# Out:
#    Pclass                                               Name  ...   Age  SibSp
# 0       3                            Braund, Mr. Owen Harris  ...  22.0      1
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  ...  38.0      1
# 2       3                             Heikkinen, Miss. Laina  ...  26.0      0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  ...  35.0      1
# 4       3                           Allen, Mr. William Henry  ...  35.0      0
#
# [5 rows x 5 columns]

# %% [markdown]
# # Plotting Histogram and Bar chart

# %%
df1['Fare'].hist(bins = 30,density = True)
plt.show()

# %%
df1['Age'].hist(bins = 30,density = True)
plt.show()

# %% [markdown]
# Identifying binary column

# %%
vars1 = [col for col in df1 if np.isin(df1[col].unique(), [0, 1]).all()] 
vars1
# Out:
# ['Survived']

# %%
df1[vars1].value_counts().plot.bar(figsize = (10,6))
